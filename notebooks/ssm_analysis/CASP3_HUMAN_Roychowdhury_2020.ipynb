# %%
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

import os
import joblib
from pathlib import Path
from tempfile import TemporaryDirectory
from loguru import logger

import pandas as pd
import numpy as np
from scipy.stats import spearmanr
from sklearn.metrics import mean_absolute_error

from predictability.models import ResidueAgnosticRegressor, PartialLeastSquares, RITARegressor, PottsRegressor
from predictability.utils import update_environment_variables, assign_ssm_folds, ProteinGym
from predictability.sm_utils import get_rita_embeddings, get_potts_emissions, read_sm_credentials
from predictability.constants import DATA_ROOT, PROJECT_ROOT, BINARY_RESIDUE_FEATURES

# %%
update_environment_variables("zsh")
read_sm_credentials("old")
DEFAULT_BUCKET = os.environ.get("AWS_DEFAULT_BUCKET")
GLOBAL_DATA_ROOT = os.environ.get("DATA_ROOT")
SEED = 1337
ds = "CASP3_HUMAN_Roychowdhury_2020"
n_folds = 10
model_names = ["Residue agnostic regressor", "Partial least squares", "Augmented Potts", "RITA regressor"]
lambda_reg = 0.1
results_dir = PROJECT_ROOT / f"results/{ds}"
results_dir.mkdir(exist_ok=True, parents=True)
rita_training_job_names = joblib.load(PROJECT_ROOT / "misc/rita_training_job_names.joblib")
potts_training_job_names = joblib.load(PROJECT_ROOT / "misc/potts_training_job_names.joblib")
gym = ProteinGym(
    proteingym_location=Path(GLOBAL_DATA_ROOT) / "public/proteingym",
    meta_data_path=Path(GLOBAL_DATA_ROOT) / "public/proteingym/substitutions_raw_DMS/DMS_substitutions.csv"
)
reference = gym.reference_information[gym.reference_information["DMS_id"] == ds]["target_seq"].values[0]

# %%
results = {
    "dataset": [],
    "model": [],
    "fold": [],
    "structural_characteristic": [],
    "is_member": [],
    "spearman": [],
    "mae": []
}

data = pd.read_csv(DATA_ROOT / f"{ds}/data.csv").reset_index()
data["residue_number"] = data["mutant"].map(lambda x: int(x[1:-1]))
structural_characteristics = pd.read_csv(DATA_ROOT / ds / "structural_characteristics.csv")
data["embedding_index"] = list(range(len(data)))
data = data.merge(structural_characteristics, on="residue_number")
embedding_indices = data["embedding_index"].values

with TemporaryDirectory() as temp_dir:
    potts_path = get_potts_emissions(
        path=temp_dir,
        dataset=ds,
        training_job_names=potts_training_job_names,
        default_bucket=DEFAULT_BUCKET
    )
    embeddings_path = get_rita_embeddings(
        path=temp_dir,
        dataset=ds,
        training_job_names=rita_training_job_names,
        default_bucket=DEFAULT_BUCKET
    )
    embeddings = np.load(embeddings_path)[embedding_indices]
    models = [
        ResidueAgnosticRegressor(wildtype_sequence=reference),
        PartialLeastSquares(),
        PottsRegressor(potts_path=potts_path, alpha=lambda_reg),
        RITARegressor(alpha=lambda_reg)
    ]

    for feature in BINARY_RESIDUE_FEATURES:
        logger.info(f"Feature: {feature}.")
        for is_member in [0, 1]:
            df = data[data[feature]==is_member].reset_index(drop=True)
            logger.info(f"Is member: {['no', 'yes'][is_member]}.")
            df = assign_ssm_folds(df, n_folds=n_folds, position_col="residue_number", random_seed=SEED)

            for test_fold in range(n_folds):
                logger.info(f"Starting fold {test_fold}.")
                train_indices = np.where(df["ssm_fold"] != test_fold)
                test_indices = np.where(df["ssm_fold"] == test_fold)
                train_data = df[df["ssm_fold"] != test_fold]
                test_data = df[df["ssm_fold"] == test_fold]

                for model, model_name in zip(models, model_names):
                    logger.info(f"Fitting {model_name}.")
                    if model_name == "RITA regressor":
                        model.fit(train_data, target="DMS_score", embeddings=embeddings[train_indices])
                        test_predictions = model.predict(test_data, embeddings=embeddings[test_indices])
                    else:
                        model.fit(train_data, target="DMS_score")
                        test_predictions = model.predict(test_data)
                    mae = mean_absolute_error(test_data["DMS_score"].values, test_predictions)
                    spearman, _ = spearmanr(test_data["DMS_score"].values, test_predictions)

                    results["dataset"].append(ds)
                    results["model"].append(model_name)
                    results["fold"].append(test_fold)
                    results["structural_characteristic"].append(feature)
                    results["is_member"].append(is_member)
                    results["mae"].append(mae)
                    results["spearman"].append(spearman)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /Library/Application Support/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /Users/floris/Library/Application Support/sagemaker/config.yaml
# 2024-03-01 11:14:34.849 | INFO     | predictability.models:__init__:149 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpq5jd847s
# 2024-03-01 11:14:41.691 | INFO     | __main__:<module>:40 - Feature: is_buried.
# 2024-03-01 11:14:41.697 | INFO     | __main__:<module>:43 - Is member: no.
# 2024-03-01 11:14:41.736 | INFO     | __main__:<module>:47 - Starting fold 0.
# 2024-03-01 11:14:41.738 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:41.891 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:14:42.337 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:43.162 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:43.170 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:43.330 | INFO     | __main__:<module>:47 - Starting fold 1.
# 2024-03-01 11:14:43.334 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:43.415 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# 2024-03-01 11:14:44.004 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:44.762 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:44.771 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:44.957 | INFO     | __main__:<module>:47 - Starting fold 2.
# 2024-03-01 11:14:44.962 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:45.014 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# 2024-03-01 11:14:45.694 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:46.412 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:46.418 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:46.594 | INFO     | __main__:<module>:47 - Starting fold 3.
# 2024-03-01 11:14:46.601 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:46.654 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:14:47.032 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:47.796 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:47.800 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:47.960 | INFO     | __main__:<module>:47 - Starting fold 4.
# 2024-03-01 11:14:47.966 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:48.027 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# 2024-03-01 11:14:48.603 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:49.353 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:49.363 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:49.546 | INFO     | __main__:<module>:47 - Starting fold 5.
# 2024-03-01 11:14:49.551 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:49.638 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:14:50.122 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:50.929 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:50.932 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:51.076 | INFO     | __main__:<module>:47 - Starting fold 6.
# 2024-03-01 11:14:51.081 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:51.128 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:14:51.572 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:52.418 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:52.445 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:52.662 | INFO     | __main__:<module>:47 - Starting fold 7.
# 2024-03-01 11:14:52.668 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:52.719 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# 2024-03-01 11:14:53.459 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:54.175 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:54.180 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:54.331 | INFO     | __main__:<module>:47 - Starting fold 8.
# 2024-03-01 11:14:54.337 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:54.395 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# 2024-03-01 11:14:55.011 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:55.855 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:55.858 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:56.025 | INFO     | __main__:<module>:47 - Starting fold 9.
# 2024-03-01 11:14:56.030 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:56.099 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:14:56.571 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:57.316 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:57.322 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:57.540 | INFO     | __main__:<module>:43 - Is member: yes.
# 2024-03-01 11:14:57.566 | INFO     | __main__:<module>:47 - Starting fold 0.
# 2024-03-01 11:14:57.570 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:57.647 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:14:58.100 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:14:58.877 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:14:58.882 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:14:59.088 | INFO     | __main__:<module>:47 - Starting fold 1.
# 2024-03-01 11:14:59.091 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:14:59.157 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:14:59.517 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:00.263 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:00.267 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:00.371 | INFO     | __main__:<module>:47 - Starting fold 2.
# 2024-03-01 11:15:00.375 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:00.423 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:00.836 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:01.567 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:01.571 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:01.691 | INFO     | __main__:<module>:47 - Starting fold 3.
# 2024-03-01 11:15:01.696 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:01.737 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:02.161 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:02.926 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:02.933 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:03.069 | INFO     | __main__:<module>:47 - Starting fold 4.
# 2024-03-01 11:15:03.076 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:03.135 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:03.503 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:04.236 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:04.244 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:04.361 | INFO     | __main__:<module>:47 - Starting fold 5.
# 2024-03-01 11:15:04.369 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:04.502 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:04.875 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:05.685 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:05.690 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:05.847 | INFO     | __main__:<module>:47 - Starting fold 6.
# 2024-03-01 11:15:05.851 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:05.920 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:06.291 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:07.021 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:07.025 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:07.200 | INFO     | __main__:<module>:47 - Starting fold 7.
# 2024-03-01 11:15:07.205 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:07.260 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:07.620 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:08.369 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:08.374 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:08.575 | INFO     | __main__:<module>:47 - Starting fold 8.
# 2024-03-01 11:15:08.579 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:08.627 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:09.024 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:09.779 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:09.782 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:09.911 | INFO     | __main__:<module>:47 - Starting fold 9.
# 2024-03-01 11:15:09.917 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:09.976 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:10.324 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:11.106 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:11.112 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:11.321 | INFO     | __main__:<module>:40 - Feature: is_connected.
# 2024-03-01 11:15:11.327 | INFO     | __main__:<module>:43 - Is member: no.
# 2024-03-01 11:15:11.359 | INFO     | __main__:<module>:47 - Starting fold 0.
# 2024-03-01 11:15:11.362 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:11.419 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:11.956 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:12.826 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:12.836 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:13.116 | INFO     | __main__:<module>:47 - Starting fold 1.
# 2024-03-01 11:15:13.119 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:13.264 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:13.746 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:14.677 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:14.681 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:14.840 | INFO     | __main__:<module>:47 - Starting fold 2.
# 2024-03-01 11:15:14.845 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:14.906 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:15.369 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:16.253 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:16.258 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:16.461 | INFO     | __main__:<module>:47 - Starting fold 3.
# 2024-03-01 11:15:16.467 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:16.528 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:17.107 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:17.957 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:17.961 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:18.182 | INFO     | __main__:<module>:47 - Starting fold 4.
# 2024-03-01 11:15:18.188 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:18.251 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:18.819 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:19.710 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:19.713 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:19.884 | INFO     | __main__:<module>:47 - Starting fold 5.
# 2024-03-01 11:15:19.899 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:20.034 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:20.548 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:21.439 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:21.447 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:21.680 | INFO     | __main__:<module>:47 - Starting fold 6.
# 2024-03-01 11:15:21.687 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:21.754 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:22.187 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:23.083 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:23.087 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:23.357 | INFO     | __main__:<module>:47 - Starting fold 7.
# 2024-03-01 11:15:23.361 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:23.510 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:15:23.961 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15:24.801 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:15:24.805 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:15:24.987 | INFO     | __main__:<module>:47 - Starting fold 8.
# 2024-03-01 11:15:24.991 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:15:25.119 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# 2024-03-01 11:15:26.609 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:15
| INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:27.767 | INFO     | __main__:<module>:43 - Is member: yes.
# 2024-03-01 11:16:27.803 | INFO     | __main__:<module>:47 - Starting fold 0.
# 2024-03-01 11:16:27.808 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:27.932 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:28.442 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:29.373 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:29.380 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:29.563 | INFO     | __main__:<module>:47 - Starting fold 1.
# 2024-03-01 11:16:29.569 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:29.646 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:30.143 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:30.993 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:31.000 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:31.181 | INFO     | __main__:<module>:47 - Starting fold 2.
# 2024-03-01 11:16:31.186 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:31.251 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:31.726 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:32.606 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:32.613 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:32.785 | INFO     | __main__:<module>:47 - Starting fold 3.
# 2024-03-01 11:16:32.790 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:32.874 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:33.325 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:34.258 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:34.265 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:34.440 | INFO     | __main__:<module>:47 - Starting fold 4.
# 2024-03-01 11:16:34.446 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:34.523 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:34.958 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:35.768 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:35.772 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:35.999 | INFO     | __main__:<module>:47 - Starting fold 5.
# 2024-03-01 11:16:36.004 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:36.094 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 6
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:36.563 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:37.362 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:37.374 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:37.554 | INFO     | __main__:<module>:47 - Starting fold 6.
# 2024-03-01 11:16:37.559 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:37.705 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:38.243 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:39.150 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:39.154 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:39.341 | INFO     | __main__:<module>:47 - Starting fold 7.
# 2024-03-01 11:16:39.347 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:39.425 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:39.909 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:40.768 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:40.773 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:41.004 | INFO     | __main__:<module>:47 - Starting fold 8.
# 2024-03-01 11:16:41.009 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:41.081 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:41.564 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:42.537 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:42.542 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-03-01 11:16:42.718 | INFO     | __main__:<module>:47 - Starting fold 9.
# 2024-03-01 11:16:42.723 | INFO     | __main__:<module>:54 - Fitting Residue agnostic regressor.
# 2024-03-01 11:16:42.808 | INFO     | __main__:<module>:54 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-03-01 11:16:43.316 | INFO     | __main__:<module>:54 - Fitting Augmented Potts.
# 2024-03-01 11:16:44.132 | INFO     | __main__:<module>:54 - Fitting RITA regressor.
# 2024-03-01 11:16:44.136 | INFO     | predictability.models:fit:253 - Fitting ridge

# %%
results_df = pd.DataFrame(results)
results_df.to_csv(results_dir / "results.csv")

# %%
results_df
# Out:
#                            dataset                       model  fold  \
# 0    CASP3_HUMAN_Roychowdhury_2020  Residue agnostic regressor     0
# 1    CASP3_HUMAN_Roychowdhury_2020       Partial least squares     0
# 2    CASP3_HUMAN_Roychowdhury_2020             Augmented Potts     0
# 3    CASP3_HUMAN_Roychowdhury_2020              RITA regressor     0
# 4    CASP3_HUMAN_Roychowdhury_2020  Residue agnostic regressor     1
# ..                             ...                         ...   ...
# 315  CASP3_HUMAN_Roychowdhury_2020              RITA regressor     8
# 316  CASP3_HUMAN_Roychowdhury_2020  Residue agnostic regressor     9
# 317  CASP3_HUMAN_Roychowdhury_2020       Partial least squares     9
# 318  CASP3_HUMAN_Roychowdhury_2020             Augmented Potts     9
# 319  CASP3_HUMAN_Roychowdhury_2020              RITA regressor     9
#
#     structural_characteristic  is_member  spearman       mae
# 0                   is_buried          0  0.472410  0.536396
# 1                   is_buried          0  0.461059  0.575510
# 2                   is_buried          0  0.665187  0.430180
# 3                   is_buried          0  0.305422  0.610596
# 4                   is_buried          0  0.371984  0.452255
# ..                        ...        ...       ...       ...
# 315              is_secondary          1  0.295344  0.559397
# 316              is_secondary          1  0.648799  0.387276
# 317              is_secondary          1  0.647484  0.440075
# 318              is_secondary          1  0.678953  0.397760
# 319              is_secondary          1  0.367685  0.481464
#
# [320 rows x 7 columns]

# %%
import plotnine as p9
from predictability.plotting import feature_mapping, color_mapping, assign_pretty_feature_names

results_df["is_member"] = results_df["is_member"].astype(bool)
results_df["Feature label"] = results_df["is_member"].apply(lambda x: "Negative" if x==False else "Positive")
results_df["Feature"] = results_df["structural_characteristic"].apply(assign_pretty_feature_names)

results_df["Structural characteristic"] = results_df[['Feature', 'Feature label']].apply(
    lambda x: feature_mapping[tuple(x)], axis=1
)
results_df["Structural characteristic"] = pd.Categorical(results_df["Structural characteristic"],
                                                     categories=["Buried", "Exposed", "Many contacts", "Few contacts",
                                                                 "Close to active site", "Distant to active site",
                                                                 "Part of helix or sheet", "Part of loop"],
                                                     ordered=True)

p = (
    p9.ggplot(
        results_df,
        p9.aes(
            "Structural characteristic",
            "spearman",
            fill="Structural characteristic",
        )
    )
    + p9.geom_boxplot(show_legend=False)
    + p9.facet_wrap("model", nrow=2, ncol=2)
    + p9.theme(figure_size=(10, 10), axis_text_x=p9.element_text(rotation=15, ha="right"))
    + p9.scale_fill_manual(values=color_mapping)
    + p9.theme(
        plot_background=p9.element_rect(fill='white'),
        panel_background=p9.element_rect(fill='white'),
        axis_title_y=p9.element_text(text="Test Spearman (ρ)", size=18),
    )
    + p9.labs(x="")
)
p.draw()
# p.save(save_dir / "supervised_performance_difference.png")
print(p)

# %%
import plotnine as p9
from predictability.plotting import feature_mapping, color_mapping, assign_pretty_feature_names

results_df["is_member"] = results_df["is_member"].astype(bool)
results_df["Feature label"] = results_df["is_member"].apply(lambda x: "Negative" if x==False else "Positive")
results_df["Feature"] = results_df["structural_characteristic"].apply(assign_pretty_feature_names)

results_df["Structural characteristic"] = results_df[['Feature', 'Feature label']].apply(
    lambda x: feature_mapping[tuple(x)], axis=1
)
results_df["Structural characteristic"] = pd.Categorical(results_df["Structural characteristic"],
                                                     categories=["Buried", "Exposed", "Many contacts", "Few contacts",
                                                                 "Close to active site", "Distant to active site",
                                                                 "Part of helix or sheet", "Part of loop"],
                                                     ordered=True)

p = (
    p9.ggplot(
        results_df,
        p9.aes(
            "Structural characteristic",
            "mae",
            fill="Structural characteristic",
        )
    )
    + p9.geom_boxplot(show_legend=False)
    + p9.facet_wrap("model", nrow=2, ncol=2)
    + p9.theme(figure_size=(10, 10), axis_text_x=p9.element_text(rotation=15, ha="right"))
    + p9.scale_fill_manual(values=color_mapping)
    + p9.theme(
        plot_background=p9.element_rect(fill='white'),
        panel_background=p9.element_rect(fill='white'),
        axis_title_y=p9.element_text(text="Test mean absolute error", size=18),
    )
    + p9.labs(x="")
)
p.draw()
# p.save(save_dir / "supervised_performance_difference.png")
print(p)

# %%
structural_characteristics = pd.read_csv(DATA_ROOT / ds / "structural_characteristics.csv")
for feat in BINARY_RESIDUE_FEATURES:
    print(feat)
    for is_member in [True, False]:
        print(f"Is member: {is_member}, n_samples:", sum(structural_characteristics[feat] == is_member))
# Out:
# is_buried
# Is member: True, n_samples: 119
# Is member: False, n_samples: 120
# is_connected
# Is member: True, n_samples: 92
# Is member: False, n_samples: 147
# is_close_to_as
# Is member: True, n_samples: 119
# Is member: False, n_samples: 120
# is_secondary
# Is member: True, n_samples: 136
# Is member: False, n_samples: 103
