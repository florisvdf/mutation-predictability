# %%
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

import os
import joblib
from pathlib import Path
from tempfile import TemporaryDirectory
from loguru import logger

import pandas as pd
import numpy as np
from scipy.stats import spearmanr
from sklearn.metrics import mean_absolute_error

from predictability.models import ResidueAgnosticRegressor, PartialLeastSquares, RITARegressor, PottsRegressor
from predictability.utils import update_environment_variables, assign_ssm_folds, read_fasta
from predictability.sm_utils import get_rita_embeddings, get_potts_emissions
from predictability.constants import DATA_ROOT, PROJECT_ROOT, BINARY_RESIDUE_FEATURES

# %%
update_environment_variables("zsh")
DEFAULT_BUCKET = os.environ.get("AWS_DEFAULT_BUCKET")
GLOBAL_DATA_ROOT = os.environ.get("DATA_ROOT")
SEED = 1337
ds = "amylase"
target = "activity_dp3"
n_folds = 10
model_names = ["Residue agnostic regressor", "Partial least squares", "Augmented Potts", "RITA regressor"]
lambda_reg = 0.1
results_dir = PROJECT_ROOT / f"results/singles/{ds}"
results_dir.mkdir(exist_ok=True, parents=True)
reference = [sequence for _, sequence in read_fasta(DATA_ROOT / "amylase/reference.fasta").items()][0]

# %%
rita_training_job_names = {
    "amylase": "huggingface-regressor-01-08-09-00"
}
potts_training_job_names = {
    "amylase": "potts-regressor-12-09-53-35"
}

# %%
results = {
    "dataset": [],
    "model": [],
    "fold": [],
    "structural_characteristic": [],
    "is_member": [],
    "spearman": [],
    "mae": [],
}

data = pd.read_csv(DATA_ROOT / f"amylase/singles.csv").reset_index()
data["embedding_index"] = list(range(len(data)))
embedding_indices = data["embedding_index"].values
data = data.dropna(subset=target)

with TemporaryDirectory() as temp_dir:
    potts_path = get_potts_emissions(
        path=temp_dir,
        dataset=ds,
        training_job_names=potts_training_job_names,
        default_bucket=DEFAULT_BUCKET
    )
    embeddings_path = get_rita_embeddings(
        path=temp_dir,
        dataset=ds,
        training_job_names=rita_training_job_names,
        default_bucket=DEFAULT_BUCKET
    )
    embeddings = np.load(embeddings_path)
    models = [
        ResidueAgnosticRegressor(wildtype_sequence=reference),
        PartialLeastSquares(),
        PottsRegressor(potts_path=potts_path, alpha=lambda_reg),
        RITARegressor(alpha=lambda_reg)
    ]

    for feature in BINARY_RESIDUE_FEATURES:
        logger.info(f"Feature: {feature}.")
        for is_member in [0, 1]:
            df = data[data[feature]==is_member].reset_index(drop=True)
            logger.info(f"Is member: {['no', 'yes'][is_member]}.")
            df = assign_ssm_folds(df, n_folds=n_folds, position_col="residue_number", random_seed=SEED)

            for test_fold in range(n_folds):
                logger.info(f"Starting fold {test_fold}.")
                train_indices = np.where(df["ssm_fold"] != test_fold)
                test_indices = np.where(df["ssm_fold"] == test_fold)
                train_data = df[df["ssm_fold"] != test_fold]
                test_data = df[df["ssm_fold"] == test_fold]

                for model, model_name in zip(models, model_names):
                    logger.info(f"Fitting {model_name}.")
                    if model_name == "RITA regressor":
                        model.fit(train_data, target=target, embeddings=embeddings[train_indices])
                        test_predictions = model.predict(test_data, embeddings=embeddings[test_indices])
                    else:
                        model.fit(train_data, target=target)
                        test_predictions = model.predict(test_data)
                    mae = mean_absolute_error(test_data[target].values, test_predictions)
                    spearman, _ = spearmanr(test_data[target].values, test_predictions)

                    results["dataset"].append(ds)
                    results["model"].append(model_name)
                    results["fold"].append(test_fold)
                    results["structural_characteristic"].append(feature)
                    results["is_member"].append(is_member)
                    results["mae"].append(mae)
                    results["spearman"].append(spearman)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /Library/Application Support/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /Users/floris/Library/Application Support/sagemaker/config.yaml
# 2024-04-10 15:57:00.445 | INFO     | predictability.models:__init__:149 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpa00kt6sn
# 2024-04-10 15:57:09.701 | INFO     | __main__:<module>:38 - Feature: is_buried.
# 2024-04-10 15:57:09.750 | INFO     | __main__:<module>:41 - Is member: no.
# 2024-04-10 15:57:09.882 | INFO     | __main__:<module>:45 - Starting fold 0.
# 2024-04-10 15:57:09.888 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:57:10.192 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:57:14.493 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:57:27.164 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:57:27.529 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:57:28.538 | INFO     | __main__:<module>:45 - Starting fold 1.
# 2024-04-10 15:57:28.548 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:57:28.957 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:57:33.153 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:57:43.284 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:57:43.342 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:57:44.310 | INFO     | __main__:<module>:45 - Starting fold 2.
# 2024-04-10 15:57:44.317 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:57:44.808 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:57:48.981 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:57:59.235 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:57:59.280 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:58:00.382 | INFO     | __main__:<module>:45 - Starting fold 3.
# 2024-04-10 15:58:00.390 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:58:00.780 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:58:04.870 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:58:14.819 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:58:14.868 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:58:15.881 | INFO     | __main__:<module>:45 - Starting fold 4.
# 2024-04-10 15:58:15.888 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:58:16.379 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:58:20.435 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:58:30.736 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:58:30.793 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:58:31.680 | INFO     | __main__:<module>:45 - Starting fold 5.
# 2024-04-10 15:58:31.688 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:58:31.984 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:58:36.131 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:58:46.174 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:58:46.217 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:58:47.183 | INFO     | __main__:<module>:45 - Starting fold 6.
# 2024-04-10 15:58:47.191 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:58:48.191 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:58:52.159 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:59:01.991 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:59:02.034 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:59:02.914 | INFO     | __main__:<module>:45 - Starting fold 7.
# 2024-04-10 15:59:02.926 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:59:03.440 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:59:07.343 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:59:17.467 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:59:17.519 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:59:18.458 | INFO     | __main__:<module>:45 - Starting fold 8.
# 2024-04-10 15:59:18.519 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:59:19.030 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:59:22.996 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:59:32.350 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:59:32.411 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:59:33.414 | INFO     | __main__:<module>:45 - Starting fold 9.
# 2024-04-10 15:59:33.427 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:59:33.946 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:59:37.974 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 15:59:48.558 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 15:59:48.655 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 15:59:49.699 | INFO     | __main__:<module>:41 - Is member: yes.
# 2024-04-10 15:59:49.995 | INFO     | __main__:<module>:45 - Starting fold 0.
# 2024-04-10 15:59:49.998 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 15:59:50.436 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 15:59:54.454 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:00:04.246 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:00:04.295 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:00:05.279 | INFO     | __main__:<module>:45 - Starting fold 1.
# 2024-04-10 16:00:05.290 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:00:05.795 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:00:09.841 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:00:20.128 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:00:20.215 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:00:21.249 | INFO     | __main__:<module>:45 - Starting fold 2.
# 2024-04-10 16:00:21.266 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:00:21.834 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:00:25.863 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:00:35.716 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:00:35.780 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:00:36.846 | INFO     | __main__:<module>:45 - Starting fold 3.
# 2024-04-10 16:00:36.867 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:00:37.480 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:00:41.448 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:00:50.711 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:00:50.777 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:00:51.751 | INFO     | __main__:<module>:45 - Starting fold 4.
# 2024-04-10 16:00:51.772 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:00:52.310 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:00:56.320 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:01:05.462 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:01:05.530 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:01:06.445 | INFO     | __main__:<module>:45 - Starting fold 5.
# 2024-04-10 16:01:06.457 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:01:06.826 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:01:10.807 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:01:20.362 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:01:20.420 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:01:21.416 | INFO     | __main__:<module>:45 - Starting fold 6.
# 2024-04-10 16:01:21.424 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:01:21.920 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:01:25.857 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:01:35.475 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:01:35.556 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:01:36.465 | INFO     | __main__:<module>:45 - Starting fold 7.
# 2024-04-10 16:01:36.473 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:01:36.936 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:01:40.902 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:01:50.086 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:01:50.159 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:01:51.054 | INFO     | __main__:<module>:45 - Starting fold 8.
# 2024-04-10 16:01:51.065 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:01:51.579 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:01:55.561 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:02:04.846 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:02:04.933 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:02:05.824 | INFO     | __main__:<module>:45 - Starting fold 9.
# 2024-04-10 16:02:05.830 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:02:06.278 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:02:10.142 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:02:20.068 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:02:20.142 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:02:21.045 | INFO     | __main__:<module>:38 - Feature: is_connected.
# 2024-04-10 16:02:21.056 | INFO     | __main__:<module>:41 - Is member: no.
# 2024-04-10 16:02:21.223 | INFO     | __main__:<module>:45 - Starting fold 0.
# 2024-04-10 16:02:21.230 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:02:21.710 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:02:26.506 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:02:38.079 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:02:38.226 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:02:39.486 | INFO     | __main__:<module>:45 - Starting fold 1.
# 2024-04-10 16:02:39.497 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:02:40.061 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:02:44.944 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:02:56.628 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:02:56.702 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:02:58.110 | INFO     | __main__:<module>:45 - Starting fold 2.
# 2024-04-10 16:02:58.127 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:02:58.623 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:03:03.259 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:03:15.407 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:03:15.496 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:03:16.697 | INFO     | __main__:<module>:45 - Starting fold 3.
# 2024-04-10 16:03:16.703 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:03:17.260 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:03:22.089 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:03:33.376 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:03:33.533 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:03:34.656 | INFO     | __main__:<module>:45 - Starting fold 4.
# 2024-04-10 16:03:34.666 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:03:35.295 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:03:40.100 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:03:51.407 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:03:51.488 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:03:52.693 | INFO     | __main__:<module>:45 - Starting fold 5.
# 2024-04-10 16:03:52.701 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:03:53.356 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:03:58.017 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:04:09.327 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:04:09.454 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:04:10.679 | INFO     | __main__:<module>:45 - Starting fold 6.
# 2024-04-10 16:04:10.683 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:04:11.322 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:04:16.210 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:04:27.487 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:04:27.589 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:04:28.809 | INFO     | __main__:<module>:45 - Starting fold 7.
# 2024-04-10 16:04:28.821 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:04:29.462 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:04:34.755 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:04:47.384 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:04:47.560 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:04:48.815 | INFO     | __main__:<module>:45 - Starting fold 8.
# 2024-04-10 16:04:48.833 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:04:49.400 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:04:54.295 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:05:06.058 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:05:06.157 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:05:07.326 | INFO     | __main__:<module>:45 - Starting fold 9.
# 2024-04-10 16:05:07.333 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:05:07.993 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:05:12.953 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:05:25.130 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:05:25.195 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:05:26.401 | INFO     | __main__:<module>:41 - Is member: yes.
# 2024-04-10 16:05:26.506 | INFO     | __main__:<module>:45 - Starting fold 0.
# 2024-04-10 16:05:26.515 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:05:26.888 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:05:30.671 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:05:39.054 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:05:39.124 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:05:39.983 | INFO     | __main__:<module>:45 - Starting fold 1.
# 2024-04-10 16:05:39.993 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:05:40.452 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:05:44.559 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:05:52.085 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:05:52.120 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:05:52.826 | INFO     | __main__:<module>:45 - Starting fold 2.
# 2024-04-10 16:05:52.838 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:05:53.213 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:05:56.511 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:06:03.835 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:06:03.883 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:06:04.678 | INFO     | __main__:<module>:45 - Starting fold 3.
# 2024-04-10 16:06:04.694 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:06:05.175 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:06:08.441 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:06:16.420 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:06:16.463 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:06:17.219 | INFO     | __main__:<module>:45 - Starting fold 4.
# 2024-04-10 16:06:17.237 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:06:17.720 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:06:21.031 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:06:28.605 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:06:28.663 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:06:29.389 | INFO     | __main__:<module>:45 - Starting fold 5.
# 2024-04-10 16:06:29.397 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:06:29.871 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:06:33.387 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:06:40.629 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:06:40.676 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:06:41.458 | INFO     | __main__:<module>:45 - Starting fold 6.
# 2024-04-10 16:06:41.463 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:06:41.904 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:06:45.496 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:06:53.090 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:06:53.127 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:06:53.947 | INFO     | __main__:<module>:45 - Starting fold 7.
# 2024-04-10 16:06:53.959 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:06:54.555 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:06:57.724 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:07:05.689 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:07:05.736 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:07:06.528 | INFO     | __main__:<module>:45 - Starting fold 8.
# 2024-04-10 16:07:06.531 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:07:06.966 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:07:10.654 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:07:18.672 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:07:18.725 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:07:19.447 | INFO     | __main__:<module>:45 - Starting fold 9.
# 2024-04-10 16:07:19.469 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:07:19.896 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:07:23.162 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:07:30.932 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:07:30.998 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:07:31.753 | INFO     | __main__:<module>:38 - Feature: is_close_to_as.
# 2024-04-10 16:07:31.771 | INFO     | __main__:<module>:41 - Is member: no.
# 2024-04-10 16:07:31.976 | INFO     | __main__:<module>:45 - Starting fold 0.
# 2024-04-10 16:07:31.982 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:07:32.433 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:07:36.540 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:07:46.135 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:07:46.183 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:07:47.037 | INFO     | __main__:<module>:45 - Starting fold 1.
# 2024-04-10 16:07:47.046 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:07:47.423 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:07:51.477 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:08:01.518 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:08:01.573 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:08:02.668 | INFO     | __main__:<module>:45 - Starting fold 2.
# 2024-04-10 16:08:02.680 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:08:03.231 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:08:07.212 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:08:18.120 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:08:18.175 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:08:19.407 | INFO     | __main__:<module>:45 - Starting fold 3.
# 2024-04-10 16:08:19.413 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:08:19.770 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:08:23.844 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:08:33.784 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:08:33.832 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:08:34.955 | INFO     | __main__:<module>:45 - Starting fold 4.
# 2024-04-10 16:08:34.970 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:08:35.579 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:08:39.680 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:08:49.799 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:08:49.855 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:08:50.869 | INFO     | __main__:<module>:45 - Starting fold 5.
# 2024-04-10 16:08:50.877 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:08:51.448 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:08:55.289 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:09:04.471 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:09:04.534 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:09:05.439 | INFO     | __main__:<module>:45 - Starting fold 6.
# 2024-04-10 16:09:05.447 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:09:06.036 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:09:09.902 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:09:19.610 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:09:19.650 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:09:20.516 | INFO     | __main__:<module>:45 - Starting fold 7.
# 2024-04-10 16:09:20.523 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:09:21.033 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:09:25.089 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:09:34.473 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:09:34.528 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:09:35.613 | INFO     | __main__:<module>:45 - Starting fold 8.
# 2024-04-10 16:09:35.621 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:09:36.045 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:09:40.109 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:09:49.663 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:09:49.732 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:09:50.903 | INFO     | __main__:<module>:45 - Starting fold 9.
# 2024-04-10 16:09:50.909 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:09:51.384 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:09:55.309 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:10:04.855 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:10:04.928 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:10:06.058 | INFO     | __main__:<module>:41 - Is member: yes.
# 2024-04-10 16:10:06.181 | INFO     | __main__:<module>:45 - Starting fold 0.
# 2024-04-10 16:10:06.187 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:10:06.447 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:10:10.722 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:10:20.948 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:10:21.032 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:10:22.184 | INFO     | __main__:<module>:45 - Starting fold 1.
# 2024-04-10 16:10:22.197 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:10:22.813 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:10:26.850 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:10:36.690 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:10:36.754 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:10:37.792 | INFO     | __main__:<module>:45 - Starting fold 2.
# 2024-04-10 16:10:37.810 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:10:38.376 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:10:42.461 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:10:51.965 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:10:52.031 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:10:53.051 | INFO     | __main__:<module>:45 - Starting fold 3.
# 2024-04-10 16:10:53.059 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:10:53.662 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:10:57.685 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:11:06.993 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:11:07.061 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:11:07.919 | INFO     | __main__:<module>:45 - Starting fold 4.
# 2024-04-10 16:11:07.940 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:11:08.503 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:11:12.498 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:11:21.909 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:11:21.967 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:11:22.986 | INFO     | __main__:<module>:45 - Starting fold 5.
# 2024-04-10 16:11:22.995 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:11:23.502 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:11:27.361 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:11:37.250 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:11:37.306 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:11:38.368 | INFO     | __main__:<module>:45 - Starting fold 6.
# 2024-04-10 16:11:38.371 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:11:38.876 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:11:43.027 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:11:52.834 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:11:52.895 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:11:53.841 | INFO     | __main__:<module>:45 - Starting fold 7.
# 2024-04-10 16:11:53.859 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:11:54.452 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:11:58.525 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:12:08.620 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:12:08.680 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:12:09.567 | INFO     | __main__:<module>:45 - Starting fold 8.
# 2024-04-10 16:12:09.580 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:12:09.955 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:12:14.576 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:12:24.796 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:12:24.886 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:12:25.915 | INFO     | __main__:<module>:45 - Starting fold 9.
# 2024-04-10 16:12:25.924 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:12:26.428 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:12:30.503 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:12:40.171 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:12:40.208 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:12:41.066 | INFO     | __main__:<module>:38 - Feature: is_secondary.
# 2024-04-10 16:12:41.082 | INFO     | __main__:<module>:41 - Is member: no.
# 2024-04-10 16:12:41.223 | INFO     | __main__:<module>:45 - Starting fold 0.
# 2024-04-10 16:12:41.235 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:12:41.594 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:12:44.844 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:12:52.380 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:12:52.422 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:12:53.287 | INFO     | __main__:<module>:45 - Starting fold 1.
# 2024-04-10 16:12:53.315 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:12:53.878 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:12:57.272 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:13:04.881 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:13:04.951 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:13:05.645 | INFO     | __main__:<module>:45 - Starting fold 2.
# 2024-04-10 16:13:05.688 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:13:06.075 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:13:09.294 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:13:16.746 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:13:16.795 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:13:17.684 | INFO     | __main__:<module>:45 - Starting fold 3.
# 2024-04-10 16:13:17.699 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:13:18.035 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:13:21.490 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:13:29.393 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:13:29.432 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:13:30.135 | INFO     | __main__:<module>:45 - Starting fold 4.
# 2024-04-10 16:13:30.148 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:13:30.553 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:13:33.647 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:13:41.505 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:13:41.542 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:13:42.298 | INFO     | __main__:<module>:45 - Starting fold 5.
# 2024-04-10 16:13:42.308 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:13:42.732 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:13:46.296 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:13:54.224 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:13:54.273 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:13:55.210 | INFO     | __main__:<module>:45 - Starting fold 6.
# 2024-04-10 16:13:55.232 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:13:55.661 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# /Users/floris/work/phd/projects/mutation-predictability/conda_env/lib/python3.8/site-packages/sklearn/cross_decomposition/_pls.py:305: UserWarning: Y residual is constant at iteration 7
#   warnings.warn(f"Y residual is constant at iteration {k}")
# 2024-04-10 16:13:58.205 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:14:05.839 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:14:05.880 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:14:06.619 | INFO     | __main__:<module>:45 - Starting fold 7.
# 2024-04-10 16:14:06.632 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:14:07.107 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:14:10.389 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:14:18.375 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:14:18.417 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:14:19.226 | INFO     | __main__:<module>:45 - Starting fold 8.
# 2024-04-10 16:14:19.243 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:14:19.779 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:14:22.938 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:14:30.066 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:14:30.118 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:14:31.059 | INFO     | __main__:<module>:45 - Starting fold 9.
# 2024-04-10 16:14:31.078 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:14:31.644 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:14:34.762 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:14:42.029 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:14:42.078 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:14:42.990 | INFO     | __main__:<module>:41 - Is member: yes.
# 2024-04-10 16:14:43.234 | INFO     | __main__:<module>:45 - Starting fold 0.
# 2024-04-10 16:14:43.247 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:14:43.700 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:14:48.482 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:15:00.793 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:15:00.885 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:15:02.098 | INFO     | __main__:<module>:45 - Starting fold 1.
# 2024-04-10 16:15:02.103 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:15:02.680 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:15:07.463 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:15:19.354 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:15:19.405 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:15:21.077 | INFO     | __main__:<module>:45 - Starting fold 2.
# 2024-04-10 16:15:21.092 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:15:21.545 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:15:26.283 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:15:37.841 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:15:37.916 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:15:39.094 | INFO     | __main__:<module>:45 - Starting fold 3.
# 2024-04-10 16:15:39.106 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:15:39.706 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:15:44.511 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:15:55.960 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:15:56.034 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:15:57.352 | INFO     | __main__:<module>:45 - Starting fold 4.
# 2024-04-10 16:15:57.367 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:15:57.733 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:16:02.421 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:16:16.537 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:16:16.653 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:16:18.263 | INFO     | __main__:<module>:45 - Starting fold 5.
# 2024-04-10 16:16:18.274 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:16:18.856 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:16:23.659 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:16:35.233 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:16:35.321 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:16:36.805 | INFO     | __main__:<module>:45 - Starting fold 6.
# 2024-04-10 16:16:36.815 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:16:37.513 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:16:42.195 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:16:55.510 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:16:55.594 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:16:56.916 | INFO     | __main__:<module>:45 - Starting fold 7.
# 2024-04-10 16:16:56.928 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:16:57.529 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:17:02.263 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:17:15.585 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:17:15.643 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:17:17.080 | INFO     | __main__:<module>:45 - Starting fold 8.
# 2024-04-10 16:17:17.084 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:17:17.659 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:17:22.408 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:17:33.859 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:17:33.935 | INFO     | predictability.models:fit:253 - Fitting ridge
# 2024-04-10 16:17:35.482 | INFO     | __main__:<module>:45 - Starting fold 9.
# 2024-04-10 16:17:35.492 | INFO     | __main__:<module>:52 - Fitting Residue agnostic regressor.
# 2024-04-10 16:17:36.039 | INFO     | __main__:<module>:52 - Fitting Partial least squares.
# 2024-04-10 16:17:40.736 | INFO     | __main__:<module>:52 - Fitting Augmented Potts.
# 2024-04-10 16:17:52.249 | INFO     | __main__:<module>:52 - Fitting RITA regressor.
# 2024-04-10 16:17:52.334 | INFO     | predictability.models:fit:253 - Fitting ridge

# %%
results_df = pd.DataFrame(results)
results_df.to_csv(results_dir / "results.csv")

# %%
import plotnine as p9
from predictability.plotting import feature_mapping, color_mapping, assign_pretty_feature_names

results_df["is_member"] = results_df["is_member"].astype(bool)
results_df["Feature label"] = results_df["is_member"].apply(lambda x: "Negative" if x==False else "Positive")
results_df["Feature"] = results_df["structural_characteristic"].apply(assign_pretty_feature_names)

results_df["Structural characteristic"] = results_df[['Feature', 'Feature label']].apply(
    lambda x: feature_mapping[tuple(x)], axis=1
)
results_df["Structural characteristic"] = pd.Categorical(results_df["Structural characteristic"],
                                                     categories=["Buried", "Exposed", "Many contacts", "Few contacts",
                                                                 "Close to active site", "Distant to active site",
                                                                 "Part of helix or sheet", "Part of loop"],
                                                     ordered=True)

p = (
    p9.ggplot(
        results_df,
        p9.aes(
            "Structural characteristic",
            "spearman",
            fill="Structural characteristic",
        )
    )
    + p9.geom_boxplot(show_legend=False)
    + p9.facet_wrap("model", nrow=2, ncol=2)
    + p9.theme(figure_size=(10, 10), axis_text_x=p9.element_text(rotation=15, ha="right"))
    + p9.scale_fill_manual(values=color_mapping)
    + p9.theme(
        plot_background=p9.element_rect(fill='white'),
        panel_background=p9.element_rect(fill='white'),
        axis_title_y=p9.element_text(text="Test Spearman (ρ)", size=18),
    )
    + p9.labs(x="")
)
p.draw()
# p.save(save_dir / "supervised_performance_difference.png")
print(p)

# %%
import plotnine as p9
from predictability.plotting import feature_mapping, color_mapping, assign_pretty_feature_names

results_df["is_member"] = results_df["is_member"].astype(bool)
results_df["Feature label"] = results_df["is_member"].apply(lambda x: "Negative" if x==False else "Positive")
results_df["Feature"] = results_df["structural_characteristic"].apply(assign_pretty_feature_names)

results_df["Structural characteristic"] = results_df[['Feature', 'Feature label']].apply(
    lambda x: feature_mapping[tuple(x)], axis=1
)
results_df["Structural characteristic"] = pd.Categorical(results_df["Structural characteristic"],
                                                     categories=["Buried", "Exposed", "Many contacts", "Few contacts",
                                                                 "Close to active site", "Distant to active site",
                                                                 "Part of helix or sheet", "Part of loop"],
                                                     ordered=True)

p = (
    p9.ggplot(
        results_df,
        p9.aes(
            "Structural characteristic",
            "mae",
            fill="Structural characteristic",
        )
    )
    + p9.geom_boxplot(show_legend=False)
    + p9.facet_wrap("model", nrow=2, ncol=2)
    + p9.theme(figure_size=(10, 10), axis_text_x=p9.element_text(rotation=15, ha="right"))
    + p9.scale_fill_manual(values=color_mapping)
    + p9.theme(
        plot_background=p9.element_rect(fill='white'),
        panel_background=p9.element_rect(fill='white'),
        axis_title_y=p9.element_text(text="Test mean absolute error", size=18),
    )
    + p9.labs(x="")
)
p.draw()
# p.save(save_dir / "supervised_performance_difference.png")
print(p)
