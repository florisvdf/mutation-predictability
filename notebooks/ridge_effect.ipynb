# %% [markdown]
# # To do
# 1. Check if RITA and Potts can run locally

# %%
# %load_ext autoreload
# %autoreload 2

import os
import joblib
from pathlib import Path
from tempfile import TemporaryDirectory
from loguru import logger

import pandas as pd
import numpy as np
from scipy.stats import spearmanr

from predictability.models import RITARegressor, PottsRegressor
from predictability.utils import update_environment_variables, assign_ssm_folds
from predictability.sm_utils import get_rita_embeddings, get_potts_emissions
from predictability.constants import DATA_ROOT, PROJECT_ROOT
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
update_environment_variables("zsh")
DEFAULT_BUCKET = os.environ.get("AWS_DEFAULT_BUCKET")
SEED = 1337
n_folds = 10
lambda_values = [0.001, 0.01, 0.1, 0.9]

# %%
datasets = [
    "CASP3_HUMAN_Roychowdhury_2020",
    "MK01_HUMAN_Brenan_2016",
    "AMIE_PSEAE_Wrenbeck_2017",
    "UBC9_HUMAN_Weile_2017",
    "SRC_HUMAN_Ahler_2019",
    "BLAT_ECOLX_Deng_2012",
    "BLAT_ECOLX_Stiffler_2015",
    "PTEN_HUMAN_Mighell_2018",
    "BLAT_ECOLX_Firnberg_2014"
]

# %%
rita_training_job_names = joblib.load(PROJECT_ROOT / "misc/rita_training_job_names.joblib")
potts_training_job_names = joblib.load(PROJECT_ROOT / "misc/potts_training_job_names.joblib")

# %%
# RITA
results = {
    "dataset": [],
    "model": [],
    "fold": [],
    "lambda_value": [],
    "spearman": [],
}
for ds in datasets:
    logger.info(f"Starting experiment on {ds}.")
    data = pd.read_csv(DATA_ROOT / f"{ds}/data.csv").reset_index()
    data["position"] = data["mutant"].map(lambda x: int(x[1:-1]))
    with TemporaryDirectory() as temp_dir:
        embeddings_path = get_rita_embeddings(
            path=temp_dir,
            dataset=ds,
            training_job_names=rita_training_job_names,
            default_bucket=DEFAULT_BUCKET
        )
        embeddings = np.load(embeddings_path)
        data = assign_ssm_folds(data, n_folds=n_folds, position_col="position", random_seed=SEED)
        for test_fold in range(n_folds):
            logger.info(f"Starting fold {test_fold}.")
            train_indices = data["ssm_fold"] != test_fold
            test_indices = data["ssm_fold"] == test_fold
            train_data = data[data["ssm_fold"] != test_fold]
            test_data = data[data["ssm_fold"] == test_fold]
            for lambda_reg in lambda_values:
                logger.info(f"Testing a lambda value of: {lambda_reg}.")
                model = RITARegressor(alpha=lambda_reg)
                model.fit(train_data, property="DMS_score", embeddings=embeddings[train_indices])
                test_predictions = model.predict(test_data, embeddings=embeddings[test_indices])
                spearman, _ = spearmanr(test_data["DMS_score"].values, test_predictions)
                results["dataset"].append(ds)
                results["model"].append("RITA regressor")
                results["fold"].append(test_fold)
                results["lambda_value"].append(lambda_reg)
                results["spearman"].append(spearman)
# Out:
# 2024-02-12 14:49:05.077 | INFO     | __main__:<module>:10 - Starting experiment on CASP3_HUMAN_Roychowdhury_2020.
# sagemaker.config INFO - Not applying SDK defaults from location: /Library/Application Support/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /Users/floris/Library/Application Support/sagemaker/config.yaml
# 2024-02-12 14:49:14.864 | INFO     | __main__:<module>:22 - Starting fold 0.
# 2024-02-12 14:49:14.865 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 14:49:22.020 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:49:22.448 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 14:49:32.456 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:49:32.862 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 14:49:40.663 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:49:41.044 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 14:49:51.313 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:49:51.733 | INFO     | __main__:<module>:22 - Starting fold 1.
# 2024-02-12 14:49:51.759 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 14:50:00.842 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:50:01.392 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 14:50:08.505 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:50:08.907 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 14:50:17.392 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:50:17.795 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 14:50:26.295 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:50:26.594 | INFO     | __main__:<module>:22 - Starting fold 2.
# 2024-02-12 14:50:26.607 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 14:50:36.016 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:50:36.387 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 14:50:45.048 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:50:45.423 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 14:50:54.103 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:50:54.387 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 14:51:03.329 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:51:03.697 | INFO     | __main__:<module>:22 - Starting fold 3.
# 2024-02-12 14:51:03.709 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 14:51:12.907 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:51:13.316 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 14:51:22.761 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:51:23.110 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 14:51:31.312 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:51:31.646 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 14:51:40.031 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:51:40.435 | INFO     | __main__:<module>:22 - Starting fold 4.
# 2024-02-12 14:51:40.453 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 14:51:48.969 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:51:49.356 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 14:51:57.857 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:51:58.233 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 14:52:09.473 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:52:09.971 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 14:52:18.781 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:52:19.097 | INFO     | __main__:<module>:10 - Starting experiment on MK01_HUMAN_Brenan_2016.
# 2024-02-12 14:52:47.497 | INFO     | __main__:<module>:22 - Starting fold 0.
# 2024-02-12 14:52:47.500 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 14:52:56.163 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:52:57.428 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 14:53:08.436 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:53:09.925 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 14:53:17.345 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:53:18.673 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 14:53:28.847 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 14:53:30.098 | INFO     | __main__:<module>:22 - Starting fold 1.
# 2024-02-12 14:53:30.128 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 14
| INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 15:20:44.256 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:20:45.356 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 15:20:53.278 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:20:54.224 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 15:21:02.250 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:21:03.434 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 15:21:11.779 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:21:12.834 | INFO     | __main__:<module>:22 - Starting fold 1.
# 2024-02-12 15:21:12.856 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 15:21:21.113 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:21:22.156 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 15:21:32.032 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:21:33.041 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 15:21:40.584 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:21:41.662 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 15:21:51.334 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:21:52.539 | INFO     | __main__:<module>:22 - Starting fold 2.
# 2024-02-12 15:21:52.578 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 15:21:59.939 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:22:00.980 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 15:22:11.227 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:22:12.294 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 15:22:19.057 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:22:20.031 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 15:22:31.649 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:22:32.698 | INFO     | __main__:<module>:22 - Starting fold 3.
# 2024-02-12 15:22:32.711 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 15:22:40.937 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:22:41.959 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 15:22:52.827 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:22:53.939 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 15:23:00.773 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:23:01.726 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 15:23:11.338 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:23:12.437 | INFO     | __main__:<module>:22 - Starting fold 4.
# 2024-02-12 15:23:12.465 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-12 15:23:19.959 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:23:20.957 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-12 15:23:30.646 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:23:31.688 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-12 15:23:39.229 | INFO     | predictability.models:fit:256 - Fitting ridge
# 2024-02-12 15:23:40.224 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-12 15:23:50.956 | INFO     | predictability.models:fit:256 - Fitting ridge

# %%
results_df = pd.DataFrame(results)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=len(datasets), figsize=(4, 40))
for i, dataset in enumerate(datasets):
    df = results_df[results_df["dataset"] == dataset]

    sns.boxplot(df, x="lambda_value", y="spearman", ax=ax[i])
    ax[i].set_title(dataset)
    ax[i].set_ylim([0, 1])
fig.tight_layout()

# %%
embeddings
# Out:
# array([[ 0.12231576, -0.31926343,  0.04499417, ..., -0.01062659,
#         -0.07151157, -0.0691978 ],
#        [ 0.14705995, -0.29927856,  0.03668432, ..., -0.01023824,
#         -0.07035129, -0.06392057],
#        [ 0.14043245, -0.32056648,  0.05078109, ..., -0.01230102,
#         -0.07228594, -0.07963827],
#        ...,
#        [ 0.11340933, -0.3055205 ,  0.03245023, ..., -0.00495341,
#         -0.07467657, -0.06221331],
#        [ 0.11306834, -0.30605835,  0.03152068, ..., -0.03427316,
#         -0.08053635, -0.06512277],
#        [ 0.11362512, -0.30482   ,  0.03240107, ..., -0.00299828,
#         -0.07780246, -0.06156464]])

# %%
# Potts
results = {
    "dataset": [],
    "model": [],
    "fold": [],
    "lambda_value": [],
    "spearman": [],
}
for ds in datasets:
    logger.info(f"Starting experiment on {ds}.")
    data = pd.read_csv(DATA_ROOT / f"{ds}/data.csv").reset_index()
    data["position"] = data["mutant"].map(lambda x: int(x[1:-1]))
    with TemporaryDirectory() as temp_dir:
        potts_path = get_potts_emissions(
            path=temp_dir,
            dataset=ds,
            training_job_names=potts_training_job_names,
            default_bucket=DEFAULT_BUCKET
        )
        data = assign_ssm_folds(data, n_folds=n_folds, position_col="position", random_seed=SEED)
        for test_fold in range(n_folds):
            logger.info(f"Starting fold {test_fold}.")
            train_data = data[data["ssm_fold"] != test_fold]
            test_data = data[data["ssm_fold"] == test_fold]
            for lambda_reg in lambda_values:
                logger.info(f"Testing a lambda value of: {lambda_reg}.")
                model = PottsRegressor(potts_path=Path(potts_path), encoder="energies", alpha=lambda_reg)
                model.fit(train_data, property="DMS_score")
                test_predictions = model.predict(test_data)
                spearman, _ = spearmanr(test_data["DMS_score"].values, test_predictions)
                results["dataset"].append(ds)
                results["model"].append("Augmented Potts")
                results["fold"].append(test_fold)
                results["lambda_value"].append(lambda_reg)
                results["spearman"].append(spearman)
# Out:
# 2024-02-14 14:32:01.592 | INFO     | __main__:<module>:10 - Starting experiment on CASP3_HUMAN_Roychowdhury_2020.
# 2024-02-14 14:32:45.245 | INFO     | __main__:<module>:22 - Starting fold 0.
# 2024-02-14 14
| INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmp066lcfjq
# 2024-02-14 14:55:33.181 | INFO     | __main__:<module>:10 - Starting experiment on PTEN_HUMAN_Mighell_2018.
# 2024-02-14 14:57:18.029 | INFO     | __main__:<module>:22 - Starting fold 0.
# 2024-02-14 14:57:18.031 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 14:57:18.031 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:57:34.815 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 14:57:34.844 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:57:50.979 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 14:57:50.983 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:58:06.591 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 14:58:06.596 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:58:22.427 | INFO     | __main__:<module>:22 - Starting fold 1.
# 2024-02-14 14:58:22.443 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 14:58:22.447 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:58:38.477 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 14:58:38.481 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:58:54.907 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 14:58:54.911 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:59:11.132 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 14:59:11.137 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:59:27.149 | INFO     | __main__:<module>:22 - Starting fold 2.
# 2024-02-14 14:59:27.175 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 14:59:27.177 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:59:43.560 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 14:59:43.586 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 14:59:59.217 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 14:59:59.223 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:00:14.997 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 15:00:15.005 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:00:30.823 | INFO     | __main__:<module>:22 - Starting fold 3.
# 2024-02-14 15:00:30.852 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 15:00:30.853 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:00:46.995 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 15:00:47.005 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:01:02.801 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 15:01:02.816 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:01:18.909 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 15:01:18.919 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:01:34.709 | INFO     | __main__:<module>:22 - Starting fold 4.
# 2024-02-14 15:01:34.730 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 15:01:34.732 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:01:50.529 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 15:01:50.542 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:02:06.677 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 15:02:06.681 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:02:22.638 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 15:02:22.642 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmpbu2jtsy4
# 2024-02-14 15:02:38.666 | INFO     | __main__:<module>:10 - Starting experiment on BLAT_ECOLX_Firnberg_2014.
# 2024-02-14 15:03:32.616 | INFO     | __main__:<module>:22 - Starting fold 0.
# 2024-02-14 15:03:32.618 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 15:03:32.620 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:03:37.121 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 15:03:37.122 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:03:41.342 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 15:03:41.344 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:03:45.482 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 15:03:45.483 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:03:49.535 | INFO     | __main__:<module>:22 - Starting fold 1.
# 2024-02-14 15:03:49.545 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 15:03:49.548 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:03:53.489 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 15:03:53.490 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:03:57.810 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 15:03:57.812 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:02.067 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 15:04:02.069 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:06.225 | INFO     | __main__:<module>:22 - Starting fold 2.
# 2024-02-14 15:04:06.231 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 15:04:06.231 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:10.229 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 15:04:10.230 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:14.225 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 15:04:14.226 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:18.151 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 15:04:18.152 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:22.051 | INFO     | __main__:<module>:22 - Starting fold 3.
# 2024-02-14 15:04:22.055 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 15:04:22.056 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:25.948 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 15:04:25.949 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:29.849 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 15:04:29.850 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:33.844 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 15:04:33.845 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:37.905 | INFO     | __main__:<module>:22 - Starting fold 4.
# 2024-02-14 15:04:37.908 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.001.
# 2024-02-14 15:04:37.909 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:41.833 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.01.
# 2024-02-14 15:04:41.834 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:45.873 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.1.
# 2024-02-14 15:04:45.875 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6
# 2024-02-14 15:04:49.975 | INFO     | __main__:<module>:26 - Testing a lambda value of: 0.9.
# 2024-02-14 15:04:49.978 | INFO     | predictability.models:__init__:150 - Loading Potts model locally from: /var/folders/d8/bxgj52rj3w934zctbjr8v2hh0000gn/T/tmphlfpezh6

# %%
results_df = pd.DataFrame(results)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=len(datasets), figsize=(4, 40))
for i, dataset in enumerate(datasets):
    df = results_df[results_df["dataset"] == dataset]

    sns.boxplot(df, x="lambda_value", y="spearman", ax=ax[i])
    ax[i].set_title(dataset)
    ax[i].set_ylim([0, 1])
fig.tight_layout()

# %% [markdown]
# 1. Prepare PE datasets for all datasets (skip asp and amye for now)
# 2. Run training jobs separately for all datasets in protest dir
# 3. Copy training job names and put in this notebook
# 4. Create function for downloading embeddings and potts params
# 5. Write evaluation loop
